# %% [markdown]
# ## Scraping the Metro Daily Ridership Numbers

# %%
import geopandas as gpd
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = gpd.read_file('./data.geojson')

# %%
df.head()
# Out:
#    Stopnum Serv                    Stopname        lat        long  \
# 0        1  Bus         PARAMOUNT / SLAUSON  33.973248 -118.113113
# 1      260  Bus               AVALON / 83RD  33.963903 -118.265278
# 2        3  Bus            JEFFERSON / 10TH  34.025471 -118.328402
# 3      261  Bus               AVALON / 87TH  33.958196 -118.265273
# 4        6  Bus  120TH \ AUGUSTUS F HAWKINS  33.924696 -118.242222
#
#           muni  LA_CCD  SUPD    zip    neighborhood      Serv_Council  \
# 0  PICO RIVERA     NaN   1.0  90660     Pico Rivera    Gateway Cities
# 1  LOS ANGELES     9.0   2.0  90003        Florence          Southbay
# 2  LOS ANGELES    10.0   2.0  90018  Jefferson Park  Westside Central
# 3  LOS ANGELES     9.0   2.0  90003   Green Meadows          Southbay
# 4       COUNTY     NaN   2.0  90059     Willowbrook    Gateway Cities
#
#         geoid10  NumLines  All_DX_ACT  All_DX_ON  All_DX_OFF  All_SA_ACT  \
# ...

# %%
[print(c) for c in df.columns]
# Out:
# Stopnum
# Serv
# Stopname
# lat
# long
# muni
# LA_CCD
# SUPD
# zip
# neighborhood
# Serv_Council
# geoid10
# NumLines
# All_DX_ACT
# All_DX_ON
# All_DX_OFF
# All_SA_ACT
# All_SA_ON
# All_SA_OFF
# All_SU_ACT
# All_SU_ON
# All_SU_OFF
# LINEDIR_1
# LINEDIR_2
# LINEDIR_3
# LINEDIR_4
# LINEDIR_5
# LINEDIR_6
# LINEDIR_7
# LINEDIR_8
# LINEDIR_9
# LINEDIR_10
# LINEDIR_11
# LINEDIR_12
# LINEDIR_13
# LINEDIR_14
# LINEDIR_15
# LINEDIR_16
# DX_ON_1
# DX_ON_2
# DX_ON_3
# DX_ON_4
# DX_ON_5
# DX_ON_6
# DX_ON_7
# DX_ON_8
# DX_ON_9
# DX_ON_10
# DX_ON_11
# DX_ON_12
# DX_ON_13
# DX_ON_14
# DX_ON_15
# DX_ON_16
# DX_OFF_1
# DX_OFF_2
# DX_OFF_3
# DX_OFF_4
# DX_OFF_5
# DX_OFF_6
# DX_OFF_7
# DX_OFF_8
# DX_OFF_9
# DX_OFF_10
# DX_OFF_11
# DX_OFF_12
# DX_OFF_13
# DX_OFF_14
# DX_OFF_15
# DX_OFF_16
# DX_ACT_1
# DX_ACT_2
# DX_ACT_3
# DX_ACT_4
# DX_ACT_5
# DX_ACT_6
# DX_ACT_7
# DX_ACT_8
# DX_ACT_9
# DX_ACT_10
# DX_ACT_11
# DX_ACT_12
# DX_ACT_13
# DX_ACT_14
# DX_ACT_15
# DX_ACT_16
# SA_ON_1
# SA_ON_2
# SA_ON_3
# ...
